# %%
import pandas as pd
import codecs as cd
import glob
import xlsxwriter
import os
from dateutil import parser
import re

# %% [markdown]
# ## 1. Commond Function
#
# Mục đích : Tạo ra các function dùng chung cho toàn bộ project

# %%
def to_number(str):
    '''
        Input : String
        Output : Float. If Null values will be return None
    '''
    temp = None
    try:
        temp = float(str)
    except ValueError:
        return None
    return temp

def to_date(column):
    '''
        Input : Pandas Serial
    '''
    tmp_date = []
    for x in column:
        try:
            tmp_date.append(parse(str(x)))
        except ValueError:
            tmp_date.append(None)
    return tmp_date

def is_date(in_data):
    # Kiểm tra str có phải dạng datetime không
    pattern1 = r'^\d\d\d\d/\d\d/\d\d$'
    pattern2 = r'^\d\d\/\d\d/\d\d$'
    pattern3 = r'^\d\d\d\d\/\d\d\/\d\d \d\d\:\d\d$'
    pattern4 = r'^\d\d\/\d\d\/\d\d \d\d\:\d\d$'
    pattern = [pattern1, pattern2, pattern3, pattern4]

    for pt in pattern:
        if re.match(pt, in_data) is not None:
            return True
    return False

def is_num(in_data):
    return in_data.replace('.','',1).isdigit()

# %% [markdown]
# ## 2. Get folder and file info
#
# Ý nghĩa các class :
# * file_info : Input (URL folder chứa data csv). Output (filename, extension, file size, file content dạng DataFrame)
# * read_from_folder : Input (URL). Output (Trả về thông tin của toàn bộ các file trong folder + Nội dung toàn bộ file content được lưu trong Panel Pandas)

# %%
class file_info(object):
    def get_fileName(url):
        return url[url.rfind('\\') + 1 :]

    def get_Extension(url):
        return url[url.rfind('.') + 1 :]
    
    def get_FileSize(url):
        return os.path.getsize(url)
    
class Read_file:
    '''
    Read context of file
    '''
    def __init__(self, in_url):
        self.url = in_url
        
        # Check dieu kien file co phai la csv hay khong
        
        # Get file name from in_url
        self.fileName = file_info.get_fileName(in_url)
        
        # Get file size
        self.file_size = file_info.get_FileSize(in_url)
        
        # Get extendion of file from in url
        self.fileExtention = file_info.get_Extension(in_url)
        
        self.file_context = ''
        self.file_columns = ''
        
        if self.fileExtention == 'csv':
            self.file_context = self.__read_csv()
            self.file_columns = self.file_context.columns
        
    def __read_csv(self):
        with cd.open(self.url, "r", "Shift-JIS", "ignore") as csv_file:
            df = pd.read_table(csv_file, sep=',')
        return df
    
    def get_context(self):
        return self.file_context
    
    def get_fileName(self):
        return self.fileName
    
    def get_fileExtension(self):
        return self.fileExtention

    def get_file_Columns(self):
        return self.file_columns
    
    def get_metadata(input_pd):
        '''
        Return list of all file with extendsion is csv in folder

        WARNING : - Chua check datatype. Dinh dang Datime. Gia tri max min cua datetime
        1. Datetime => Dua ra khoang tu nam nao toi nam nao => Dua ra thong ke du lieu moi nam chiem bao nhieu %
        2. String => Dua ra duoc do dai cua string => Dua ra khoang max min ki tu
        3. Int => Dua ra gia tri Max Min

        :param fileType: DataFrame
        :return: DataFrame and add 3 columns with Category, Size and Sample Data
        '''
        # Validate input
        if isinstance(input_pd, pd.DataFrame) == False:
            print('Input values is not Dataframe')
            return

        contentFile = input_pd.copy()

        rows_nums = len(contentFile)

        # IF distinct value numbers > 10% then that values is continues data type
        CATEGORY_DEFINITION = 0.1
        TOP_UNIQUE = 10
        PRECISION = 2

        unique_values_values = []

        cols_name = []

        # Duyet toan bo columns name cua table 
        for col_name in contentFile.columns:
            # Get each columns name
            cols_name.append(col_name)

            # Get unique values
            unique_values = contentFile[str(col_name)].unique()

            # Get numbers of unique values
            unique_nums = len(unique_values)

            # Category Type
            category_type = ''

            # Get rate of each unique values
            unique_values_rate = {}

            # Get Null values
            null_nums = contentFile[col_name].isnull().sum()

            # Get Min, Max values
            min_value, max_value = None, None
            try:
                min_value = float(contentFile.dropna()[col_name].min())
                max_value = float(contentFile.dropna()[col_name].max())
            except ValueError:
                min_value, max_value = None, None
            values_range = str([min_value, max_value])

            if unique_nums > (rows_nums * CATEGORY_DEFINITION):
                unique_values = None
                unique_nums = None
                category_type = 'Continuous'
            else:
                if unique_nums == 2:
                    category_type = 'Binary'
                else:
                    category_type = 'Ordinal'

                # Dat try catch cho viec /0
                try:
                    unique_values_rate = str(pd.Series(contentFile.groupby([col_name])[col_name].count()/rows_nums *100).round(decimals = PRECISION)[:TOP_UNIQUE].to_dict())
                except ValueError:
                    unique_values_rate = None

            # Add toan bo gia tri vao List theo cau truc [<Gia tri Unique>, <So luong gia tri unique>, <Data Category>]
            add_rows = {
                        'Values_Range' : values_range,
                        'Null_nums' : null_nums,
                        'Rows_nums' : rows_nums,
                        'Unique_values' : str(unique_values), 
                        'Unique_nums' : unique_nums, 
                        'Category_types' : category_type,
                        'Unique_values_rate' : unique_values_rate
                        }

            unique_values_values.append(add_rows)

        # Return Table with all values
        return pd.DataFrame(unique_values_values, index = cols_name)

# %%
class Read_from_folder:
    '''
    Read data from csv file
    '''
    def __init__(self, in_folder_url):
        self.folder_url = in_folder_url
        self.csv_url = self.__read_csv_url()
        self.csv_name = self.__read_csv_name()
        self.csv_filesize = self.__filesize()
        self.csv_summarize = self.__set_summarize_data()
        self.csv_context = self.__set_content()
        self.csv_summarize_metadata = self.__set_summarize_meta_data()

    def __read_csv_url(self):
        return glob.glob(self.folder_url+'\\*.csv')
    
    def __read_csv_name(self):
        csv_name = []
        for url in self.csv_url:
            csv_name.append(file_info.get_fileName(url))
        return csv_name
    
    def __filesize(self):
        file_size = []
        for url in self.csv_url:
            file_size.append(file_info.get_FileSize(url))
        return file_size
    
    def __set_content(self):
        data = {}
        for idx, val in enumerate(self.csv_url):
            file = Read_file(val)
            data[self.csv_name[idx]] = file.get_context()
        return data
    
    def __set_summarize_data(self):
        info = { \
                    'file_name': self.csv_name,
                    'file_size': self.csv_filesize,
               }
        return pd.DataFrame(info)
    
    def __set_summarize_meta_data(self):
        data = {}
        for idx, val in enumerate(self.csv_name):
            data[idx] = Read_file.get_metadata(self.csv_context[val])
        return data
    
    def get_csv_url(self):
        '''
        Return list of all file with extendsion is csv in folder
        :param fileType: No
        :return: URL with file name
        '''        
        return self.csv_url
    
    def get_csv_filename(self):
        return self.csv_name
    
    def get_csv_filesize(self):
        return self.csv_filesize
    
    def get_summarize_info(self):
        return self.csv_summarize
    
    def get_summarize_metadata(self):
        return self.csv_summarize_metadata
    
    def get_all_dataframe(self):
        return self.csv_context

# %% [markdown]
# # 3. Get content of data

# %% [markdown]
# # 4. Export meta data into Excel file

# %%
class Export_metadata:
    '''
    Read file in input folder
    '''
    def __init__(self, out_url, sheet_name):
        self.URL = out_url
        self.sheet_name = sheet_name.copy()

    def write_into_sheet(self, data_input, in_sheet_name):
        data_input.to_excel(self.URL, sheet_name=in_sheet_name)

    def create_excel(self, dashboard = False):
        '''
        Create Excel file with sheet name is file in folder
        :return: Excel File
        '''
        tmp_sheet_name = self.sheet_name
        
        if dashboard:
            tmp_sheet_name.append('Dashboard')
            
        workbook = xlsxwriter.Workbook(self.URL)
        for s_name in tmp_sheet_name:
            workbook.add_worksheet(s_name)
        workbook.close()

# %%
# I. Tong quan

# 1.1 Define URL_PATH
URL_PATH = r'D:\02_Python\00_data\\'

# 1.2 Read data info with read_input
input_data = Read_from_folder(URL_PATH)

# 1.3 Get summarize data info
input_data.get_summarize_info()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   # This is added back by InteractiveShellApp.init_path()
#                   file_name  file_size
# 0  311-service-requests.csv   55163834
# 1                 bikes.csv      13807
# 2                  test.csv      28629
# 3                 train.csv      61194
# 4          weather_2012.csv     512557

# %%
# II. Read all data into Data Panel
meta_data = input_data.get_all_dataframe()

# %% [markdown]
# ### III. Read each data info into Pandas Dataframe

# %%
meta_data_summarize = input_data.get_summarize_metadata()

# %%
meta_data_summarize[0]
# Out:
#                                Category_types  Null_nums  Rows_nums  \
# Unique Key                         Continuous          0     111069
# Created Date                       Continuous          0     111069
# Closed Date                        Continuous      50799     111069
# Agency                                Ordinal          0     111069
# Agency Name                           Ordinal          0     111069
# Complaint Type                        Ordinal          0     111069
# Descriptor                            Ordinal        456     111069
# Location Type                         Ordinal      32047     111069
# Incident Zip                          Ordinal      12262     111069
# Incident Address                   Continuous      26628     111069
# Street Name                           Ordinal      26637     111069
# Cross Street 1                        Ordinal      26341     111069
# Cross Street 2                        Ordinal      27064     111069
# Intersection Street 1                 Ordinal      91705     111069
# Intersection Street 2                 Ordinal      91703     111069
# Address Type                          Ordinal       8822     111069
# City                                  Ordinal      12215     111069
# Landmark                              Ordinal     110974     111069
# Facility Type                         Ordinal      91965     111069
# Status                                Ordinal          0     111069
# Due Date                           Continuous      71830     111069
# Resolution Action Updated Date     Continuous      14562     111069
# Community Board                       Ordinal          0     111069
# Borough                               Ordinal          0     111069
# X Coordinate (State Plane)         Continuous      12926     111069
# Y Coordinate (State Plane)         Continuous      12926     111069
# Park Facility Name                    Ordinal          0     111069
# Park Borough                          Ordinal          0     111069
# School Name                           Ordinal          0     111069
# School Number                         Ordinal         21     111069
# School Region                         Ordinal        545     111069
# School Code                           Ordinal        545     111069
# School Phone Number                   Ordinal          0     111069
# School Address                        Ordinal          0     111069
# School City                           Ordinal          0     111069
# School State                           Binary          0     111069
# School Zip                            Ordinal          0     111069
# School Not Found                      Ordinal      72085     111069
# School or Citywide Complaint          Ordinal     111069     111069
# Vehicle Type                          Ordinal     110970     111069
# Taxi Company Borough                  Ordinal     110952     111069
# Taxi Pick Up Location                 Ordinal     110010     111069
# Bridge Highway Name                   Ordinal     110884     111069
# Bridge Highway Direction              Ordinal     110884     111069
# Road Ramp                             Ordinal     110889     111069
# Bridge Highway Segment                Ordinal     110850     111069
# Garage Lot Name                       Ordinal     111020     111069
# Ferry Direction                       Ordinal     111045     111069
# Ferry Terminal Name                   Ordinal     110999     111069
# Latitude                           Continuous      12926     111069
# Longitude                          Continuous      12926     111069
# Location                           Continuous      12926     111069
#
#                                 Unique_nums  \
# Unique Key                              NaN
# Created Date                            NaN
# Closed Date                             NaN
# Agency                                 26.0
# Agency Name                           135.0
# Complaint Type                        165.0
# Descriptor                            789.0
# Location Type                          91.0
# Incident Zip                          442.0
# Incident Address                        NaN
# Street Name                          5923.0
# Cross Street 1                       5734.0
# Cross Street 2                       5758.0
# Intersection Street 1                4370.0
# Intersection Street 2                4700.0
# Address Type                            6.0
# City                                  143.0
# Landmark                               33.0
# Facility Type                           4.0
# Status                                  7.0
# Due Date                                NaN
# Resolution Action Updated Date          NaN
# Community Board                        77.0
# Borough                                 6.0
# X Coordinate (State Plane)              NaN
# Y Coordinate (State Plane)              NaN
# Park Facility Name                    337.0
# Park Borough                            6.0
# School Name                           337.0
# School Number                         292.0
# School Region                          12.0
# School Code                            61.0
# School Phone Number                    58.0
# School Address                        334.0
# School City                            32.0
# School State                            2.0
# School Zip                            130.0
# School Not Found                        3.0
# School or Citywide Complaint            1.0
# Vehicle Type                            4.0
# Taxi Company Borough                    6.0
# Taxi Pick Up Location                   8.0
# Bridge Highway Name                    38.0
# Bridge Highway Direction               39.0
# Road Ramp                               3.0
# Bridge Highway Segment                161.0
# Garage Lot Name                        18.0
# Ferry Direction                         3.0
# Ferry Terminal Name                    40.0
# Latitude                                NaN
# Longitude                               NaN
# Location                                NaN
#
#                                                                     Unique_values  \
# Unique Key                                                                   None
# Created Date                                                                 None
# Closed Date                                                                  None
# Agency                          ['NYPD' 'DOHMH' 'DOT' 'TLC' 'HRA' 'DSNY' 'HPD'...
# Agency Name                     ['New York City Police Department'\n 'Departme...
# Complaint Type                  ['Noise - Street/Sidewalk' 'Illegal Parking' '...
# Descriptor                      ['Loud Talking' 'Commercial Overnight Parking'...
# Location Type                   ['Street/Sidewalk' 'Club/Bar/Restaurant' 'Vaca...
# Incident Zip                    [11432.0 11378.0 10032.0 10023.0 10027.0 11372...
# Incident Address                                                             None
# Street Name                     ['169 STREET' '58 AVENUE' 'BROADWAY' ... 'CROS...
# Cross Street 1                  ['90 AVENUE' '58 PLACE' 'WEST 171 STREET' ...\...
# Cross Street 2                  ['91 AVENUE' '59 STREET' 'WEST 172 STREET' ......
# Intersection Street 1           [nan 'STRANG AVENUE' 'WEST   99 STREET' ... 'W...
# Intersection Street 2           [nan 'AMUNDSON AVENUE' 'BROADWAY' ... 'REED ST...
# Address Type                    ['ADDRESS' 'BLOCKFACE' 'INTERSECTION' 'LATLONG...
# City                            ['JAMAICA' 'MASPETH' 'NEW YORK' 'JACKSON HEIGH...
# Landmark                        [nan 'CENTRAL PARK' 'BARCLAYS CENTER' 'J F K A...
# Facility Type                             ['Precinct' nan 'DSNY Garage' 'School']
# Status                          ['Assigned' 'Open' 'Closed' 'Pending' 'Email S...
# Due Date                                                                     None
# Resolution Action Updated Date                                               None
# Community Board                 ['12 QUEENS' '05 QUEENS' '12 MANHATTAN' '07 MA...
# Borough                         ['QUEENS' 'MANHATTAN' 'BROOKLYN' 'BRONX' 'STAT...
# X Coordinate (State Plane)                                                   None
# Y Coordinate (State Plane)                                                   None
# Park Facility Name              ['Unspecified' 'Crotona Park - Bathgate Playgr...
# Park Borough                    ['QUEENS' 'MANHATTAN' 'BROOKLYN' 'BRONX' 'STAT...
# School Name                     ['Unspecified' 'Crotona Park - Bathgate Playgr...
# School Number                   ['Unspecified' 'X010-12' 'M099' '282' 'B113A' ...
# School Region                   ['Unspecified' nan 'Region 8' 'Region 7' 'Regi...
# School Code                     ['Unspecified' nan '13K282' '21K098' '28Q139' ...
# School Phone Number             ['Unspecified' '7184301800' '2124080100' 'NA 0...
# School Address                  ['Unspecified' 'Fulton Avenue, East 173rd to 1...
# School City                     ['Unspecified' 'BRONX' 'NEW YORK' 'BROOKLYN' '...
# School State                                                 ['Unspecified' 'NY']
# School Zip                      ['Unspecified' '10456' '10033' '11217' '11201'...
# School Not Found                                                    ['N' nan 'Y']
# School or Citywide Complaint                                                [nan]
# Vehicle Type                    [nan 'Car Service' 'Ambulette / Paratransit' '...
# Taxi Company Borough            [nan 'BRONX' 'BROOKLYN' 'STATEN ISLAND' 'MANHA...
# Taxi Pick Up Location           [nan 'Other' 'La Guardia Airport' 'Intersectio...
# Bridge Highway Name             [nan 'BQE/Gowanus Expwy' 'Bruckner Expwy' 'Kos...
# Bridge Highway Direction        [nan 'West/Brooklyn Bound' 'East/Bronx Bound' ...
# Road Ramp                                                  [nan 'Roadway' 'Ramp']
# Bridge Highway Segment          [nan 'Brooklyn-Queens Expwy (West Leg) - North...
# Garage Lot Name                 [nan 'Far Rockaway #2 Field' 'Steinway #1 and ...
# Ferry Direction                     [nan 'Manhattan Bound' 'Staten Island Bound']
# Ferry Terminal Name             [nan 'Kennedy' 'MERSEDES LUNA' 'Whitehall Term...
# Latitude                                                                     None
# Longitude                                                                    None
# Location                                                                     None
#
#                                                                Unique_values_rate  \
# Unique Key                                                                     {}
# Created Date                                                                   {}
# Closed Date                                                                    {}
# Agency                          {'3-1-1': 0.08, 'CHALL': 0.07, 'COIB': 0.0, 'D...
# Agency Name                     {'3-1-1 Call Center': 0.03, '311 Executive Off...
# Complaint Type                  {'APPLIANCE': 0.4, 'Adopt-A-Basket': 0.0, 'Age...
# Descriptor                      {'1 Missed Collection': 0.41, '1 or 2': 0.12, ...
# Location Type                   {'1-2 Family Dwelling': 0.51, '1-2 Family Mixe...
# Incident Zip                    {0.0: 0.0, 83.0: 0.01, 6901.0: 0.0, 7087.0: 0....
# Incident Address                                                               {}
# Street Name                     {'000': 0.0, '1': 0.0, '1 AVE': 0.0, '1 AVENUE...
# Cross Street 1                  {'1 AVE': 0.01, '1 AVENUE': 0.37, '1 COURT': 0...
# Cross Street 2                  {'1 AVE': 0.0, '1 AVENUE': 0.64, '1 AVENUE LOO...
# Intersection Street 1           {'1 AVE': 0.05, '1 AVENUE': 0.05, '1 PLACE': 0...
# Intersection Street 2           {'1 AVE': 0.01, '1 AVENUE': 0.12, '1 PLACE': 0...
# Address Type                    {'ADDRESS': 70.8, 'BLOCKFACE': 2.87, 'INTERSEC...
# City                            {'ARVERNE': 0.02, 'ASTORIA': 0.61, 'Arverne': ...
# Landmark                        {'BARCLAYS CENTER': 0.0, 'BARTEL PRITCHARD SQU...
# Facility Type                   {'DSNY Garage': 3.35, 'Precinct': 13.77, 'Scho...
# Status                          {'Assigned': 5.57, 'Closed': 51.47, 'Email Sen...
# Due Date                                                                       {}
# Resolution Action Updated Date                                                 {}
# Community Board                 {'0 Unspecified': 6.4, '01 BRONX': 0.79, '01 B...
# Borough                         {'BRONX': 17.72, 'BROOKLYN': 29.61, 'MANHATTAN...
# X Coordinate (State Plane)                                                     {}
# Y Coordinate (State Plane)                                                     {}
# Park Facility Name              {'146 St Playground': 0.0, '79th Street Boat B...
# Park Borough                    {'BRONX': 17.72, 'BROOKLYN': 29.61, 'MANHATTAN...
# School Name                     {'146 St Playground': 0.0, '79th Street Boat B...
# School Number                   {'001': 0.0, '009': 0.0, '011': 0.0, '015': 0....
# School Region                   {'Region 1': 0.01, 'Region 10': 0.01, 'Region ...
# School Code                     {'01M188': 0.0, '01M361': 0.0, '02M001': 0.0, ...
# School Phone Number             {'2122190258': 0.0, '2122553705': 0.0, '212348...
# School Address                  {'100 Hester Street': 0.0, '100 West 84 Street...
# School City                     {'ASTORIA': 0.01, 'BAYSIDE': 0.01, 'BELLEROSE'...
# School State                                   {'NY': 0.57, 'Unspecified': 99.43}
# School Zip                      {'10001': 0.0, '10002': 0.01, '10003': 0.01, '...
# School Not Found                                          {'N': 35.09, 'Y': 0.01}
# School or Citywide Complaint                                                   {}
# Vehicle Type                    {'Ambulette / Paratransit': 0.01, 'Car Service...
# Taxi Company Borough            {'BRONX': 0.02, 'BROOKLYN': 0.03, 'MANHATTAN':...
# Taxi Pick Up Location           {'Grand Central Station': 0.01, 'Intersection'...
# Bridge Highway Name             {'Alexander Hamilton/I-95 Cross Bronx Br': 0.0...
# Bridge Highway Direction        {'Bronx Bound': 0.0, 'Bronx/North Bound': 0.0,...
# Road Ramp                                         {'Ramp': 0.05, 'Roadway': 0.11}
# Bridge Highway Segment          {'1-1-896272126': 0.0, '1-1-896376891': 0.0, '...
# Garage Lot Name                 {'Astoria Field': 0.0, 'Ave M Field': 0.0, 'Ba...
# Ferry Direction                 {'Manhattan Bound': 0.01, 'Staten Island Bound...
# Ferry Terminal Name             {'Austen': 0.0, 'BRIGID OCONNOR': 0.0, 'Barber...
# Latitude                                                                       {}
# Longitude                                                                      {}
# Location                                                                       {}
#
#                                Values_Range
# Unique Key                       [nan, nan]
# Created Date                     [nan, nan]
# Closed Date                      [nan, nan]
# Agency                           [nan, nan]
# Agency Name                      [nan, nan]
# Complaint Type                   [nan, nan]
# Descriptor                       [nan, nan]
# Location Type                    [nan, nan]
# Incident Zip                     [nan, nan]
# Incident Address                 [nan, nan]
# Street Name                      [nan, nan]
# Cross Street 1                   [nan, nan]
# Cross Street 2                   [nan, nan]
# Intersection Street 1            [nan, nan]
# Intersection Street 2            [nan, nan]
# Address Type                     [nan, nan]
# City                             [nan, nan]
# Landmark                         [nan, nan]
# Facility Type                    [nan, nan]
# Status                           [nan, nan]
# Due Date                         [nan, nan]
# Resolution Action Updated Date   [nan, nan]
# Community Board                  [nan, nan]
# Borough                          [nan, nan]
# X Coordinate (State Plane)       [nan, nan]
# Y Coordinate (State Plane)       [nan, nan]
# Park Facility Name               [nan, nan]
# Park Borough                     [nan, nan]
# School Name                      [nan, nan]
# School Number                    [nan, nan]
# School Region                    [nan, nan]
# School Code                      [nan, nan]
# School Phone Number              [nan, nan]
# School Address                   [nan, nan]
# School City                      [nan, nan]
# School State                     [nan, nan]
# School Zip                       [nan, nan]
# School Not Found                 [nan, nan]
# School or Citywide Complaint     [nan, nan]
# Vehicle Type                     [nan, nan]
# Taxi Company Borough             [nan, nan]
# Taxi Pick Up Location            [nan, nan]
# Bridge Highway Name              [nan, nan]
# Bridge Highway Direction         [nan, nan]
# Road Ramp                        [nan, nan]
# Bridge Highway Segment           [nan, nan]
# Garage Lot Name                  [nan, nan]
# Ferry Direction                  [nan, nan]
# Ferry Terminal Name              [nan, nan]
# Latitude                         [nan, nan]
# Longitude                        [nan, nan]
# Location                         [nan, nan]

# %%
meta_data_summarize[1]
# Out:
#                                    Category_types  Null_nums  Rows_nums  \
# Date                                   Continuous          0        310
# Berri 1                                Continuous          0        310
# Br饕euf (donn馥s non disponibles)           Ordinal        310        310
# Cte-Sainte-Catherine                   Continuous          0        310
# Maisonneuve 1                          Continuous          0        310
# Maisonneuve 2                          Continuous          0        310
# du Parc                                Continuous          0        310
# Pierre-Dupuy                           Continuous          0        310
# Rachel1                                Continuous          0        310
# St-Urbain (donn馥s non disponibles)        Ordinal        310        310
#
#                                     Unique_nums Unique_values  \
# Date                                        NaN          None
# Berri 1                                     NaN          None
# Br饕euf (donn馥s non disponibles)             1.0         [nan]
# Cte-Sainte-Catherine                        NaN          None
# Maisonneuve 1                               NaN          None
# Maisonneuve 2                               NaN          None
# du Parc                                     NaN          None
# Pierre-Dupuy                                NaN          None
# Rachel1                                     NaN          None
# St-Urbain (donn馥s non disponibles)          1.0         [nan]
#
#                                    Unique_values_rate Values_Range
# Date                                               {}   [nan, nan]
# Berri 1                                            {}   [nan, nan]
# Br饕euf (donn馥s non disponibles)                    {}   [nan, nan]
# Cte-Sainte-Catherine                               {}   [nan, nan]
# Maisonneuve 1                                      {}   [nan, nan]
# Maisonneuve 2                                      {}   [nan, nan]
# du Parc                                            {}   [nan, nan]
# Pierre-Dupuy                                       {}   [nan, nan]
# Rachel1                                            {}   [nan, nan]
# St-Urbain (donn馥s non disponibles)                 {}   [nan, nan]

# %%
meta_data_summarize[2]
# Out:
#             Category_types  Null_nums  Rows_nums  Unique_nums  \
# PassengerId     Continuous          0        418          NaN
# Pclass             Ordinal          0        418          3.0
# Name            Continuous          0        418          NaN
# Sex                 Binary          0        418          2.0
# Age             Continuous         86        418          NaN
# SibSp              Ordinal          0        418          7.0
# Parch              Ordinal          0        418          8.0
# Ticket          Continuous          0        418          NaN
# Fare            Continuous          1        418          NaN
# Cabin           Continuous        327        418          NaN
# Embarked           Ordinal          0        418          3.0
#
#                  Unique_values  \
# PassengerId               None
# Pclass                 [3 2 1]
# Name                      None
# Sex          ['male' 'female']
# Age                       None
# SibSp          [0 1 2 3 4 5 8]
# Parch        [0 1 3 2 4 6 5 9]
# Ticket                    None
# Fare                      None
# Cabin                     None
# Embarked         ['Q' 'S' 'C']
#
#                                             Unique_values_rate  \
# PassengerId                                                 {}
# Pclass                           {1: 25.6, 2: 22.25, 3: 52.15}
# Name                                                        {}
# Sex                           {'female': 36.36, 'male': 63.64}
# Age                                                         {}
# SibSp        {0: 67.7, 1: 26.32, 2: 3.35, 3: 0.96, 4: 0.96,...
# Parch        {0: 77.51, 1: 12.44, 2: 7.89, 3: 0.72, 4: 0.48...
# Ticket                                                      {}
# Fare                                                        {}
# Cabin                                                       {}
# Embarked                    {'C': 24.4, 'Q': 11.0, 'S': 64.59}
#
#                 Values_Range
# PassengerId  [904.0, 1306.0]
# Pclass            [1.0, 3.0]
# Name            [None, None]
# Sex             [None, None]
# Age              [1.0, 76.0]
# SibSp             [0.0, 3.0]
# Parch             [0.0, 4.0]
# Ticket          [None, None]
# Fare         [0.0, 512.3292]
# Cabin           [None, None]
# Embarked        [None, None]
